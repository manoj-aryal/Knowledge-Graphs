# %%
# You need to write down your own code here
# Task: Given any head entity name (e.g. Q30) and relation name (e.g. P36), you need to output the top 10 closest tail entity names.
# File entity2vec.vec and relation2vec.vec are 50-dimensional entity and relation embeddings.
# If you use the embeddings learned from Problem 1, you will get extra credits.

import numpy as np
import tensorflow as tf
import os
import time
import datetime

def load_file(fname, skip=False):
    file = {}
    with open(fname) as i:
        if skip:
            next(i)
        for line in i:
            (key, val) = line.split()
            file[key] = int(val)
    return file


file_e = load_file('data/entity2id.txt', True)
file_r = load_file('data/relation2id.txt', True)

file_vec_e = np.loadtxt('data/entity2vec.vec')
file_vec_r = np.loadtxt('data/relation2vec.vec')

# %%
def return_vector(name, file_id, array):
    id = file_id[name]
    vector = array[id]
    return vector

def e_function(h, r, t):
    e = np.linalg.norm(h+r-t, axis=0)
    return e

print('Question No.1:')
print('')
h = return_vector('Q30', file_e, file_vec_e)
r = return_vector('P36', file_r, file_vec_r)
score = [e_function(h,r,t) for t in file_vec_e]



id_sorted = np.argsort(score, axis=0)[0:15]
  
for id in id_sorted:
    for k, v in file_e.items():
        if id == v:
            print(k, v, score[id])
            

print('')
print('Question No.2:')
print('')
h = return_vector('Q30', file_e, file_vec_e)
t = return_vector('Q49', file_e, file_vec_e)
score = [e_function(h,r,t) for r in file_vec_r]



id_sorted = np.argsort(score, axis=0)[0:15]
  
for id in id_sorted:
    for k, v in file_r.items():
        if id == v:
            print(k, v, score[id])
# Out:
# Question No.1:
#
# Q60 1072 0.33296765616347784
# Q61 1822 0.3669497780391753
# Q65 3729 0.37644162962536437
# Q47164 7440 0.38493521327750724
# Q1297 1139 0.39746816795562384
# Q1345 2528 0.4191167088198704
# Q127856 23468 0.4225420284492419
# Q23556 10792 0.42513340044037945
# Q12439 971 0.4341413142157747
# Q34404 6639 0.44039429204747876
# Q16554 9485 0.4478273134914841
# Q812 1993 0.45301452196921904
# Q5092 5678 0.45779146724900843
# Q18419 2729 0.4596060041677001
# Q100 3736 0.4617284834412969
#
# Question No.2:
#
# P30 19 0.6272077065446502
# P2184 304 0.7932530999756635
# P150 14 0.8097678897542184
# P785 356 0.8127030976500581
# P129 243 0.8227697116441514
# P914 225 0.8251698675993931
# P1589 28 0.839054765330607
# P22 66 0.8443554433258543
# P306 52 0.8484987763037729
# P1066 92 0.8567388531536316
# P1657 213 0.8606784386000383
# P2670 365 0.8614148709332803
# P789 335 0.8622428581368478
# P289 358 0.867338037890072
# P451 155 0.8693044343151598
